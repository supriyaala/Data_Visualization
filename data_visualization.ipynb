# %%
import pandas as ps
songs = ps.read_csv("spotify_songs_dataset.csv")

# %%
songs
# Out:
#        song_id               song_title             artist              album  \
# 0       SP0001  Space executive series.       Sydney Clark              What.
# 1       SP0002     Price last painting.  Connor Peters DDS   Nature politics.
# 2       SP0003                   Piece.         Anna Keith             Visit.
# 3       SP0004     Power industry your.    Zachary Simpson  Behavior evening.
# 4       SP0005      Food animal second.  Christopher Mcgee             Front.
# ...        ...                      ...                ...                ...
# 49995  SP49996      Event push do body.   Shelley Robinson         Wrong cup.
# 49996  SP49997      Share clearly role.   Jennifer Kennedy     That actually.
# 49997  SP49998      Wonder type simply.       Hailey Walsh    South Democrat.
# 49998  SP49999                 Company.       Leah Coleman             Front.
# 49999  SP50000              Woman plan.       Daniel Brown             Three.
#
# ...

# %%
songs.head(11)
# Out:
#    song_id               song_title             artist                album  \
# 0   SP0001  Space executive series.       Sydney Clark                What.
# 1   SP0002     Price last painting.  Connor Peters DDS     Nature politics.
# 2   SP0003                   Piece.         Anna Keith               Visit.
# 3   SP0004     Power industry your.    Zachary Simpson    Behavior evening.
# 4   SP0005      Food animal second.  Christopher Mcgee               Front.
# 5   SP0006        Whatever Mr send.        Nathan King  Various experience.
# 6   SP0007                Each leg.      Joshua Santos           Determine.
# 7   SP0008       Person then enjoy.      Leonard Brown           Sense lot.
# 8   SP0009                    Poor.       William Ford        Organization.
# 9   SP0010            East husband.      Susan Harrell           List item.
# 10  SP0011    Mother building well.      Shannon Moore          Process if.
#
# ...

# %%
songs['artist'].value_counts().head(10)
# Out:
# Michael Smith          23
# Michael Johnson        20
# John Smith             20
# David Jones            19
# Christopher Johnson    17
# David Johnson          16
# Robert Williams        16
# David Smith            15
# Amanda Smith           15
# Christopher Smith      15
# Name: artist, dtype: int64

# %%
songs[['artist','album']]
# Out:
#                   artist              album
# 0           Sydney Clark              What.
# 1      Connor Peters DDS   Nature politics.
# 2             Anna Keith             Visit.
# 3        Zachary Simpson  Behavior evening.
# 4      Christopher Mcgee             Front.
# ...                  ...                ...
# 49995   Shelley Robinson         Wrong cup.
# 49996   Jennifer Kennedy     That actually.
# 49997       Hailey Walsh    South Democrat.
# 49998       Leah Coleman             Front.
# 49999       Daniel Brown             Three.
#
# [50000 rows x 2 columns]

# %%
songs.plot()
# Out:
# <AxesSubplot:>

# %%
songs.plot(kind = 'scatter', x = 'duration', y = 'stream')
# Out:
# <AxesSubplot:xlabel='duration', ylabel='stream'>

# %%
songs.plot(kind = 'hist', x = 'duration')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
songs.dropna()
# Out:
#        song_id             song_title             artist                album  \
# 10      SP0011  Mother building well.      Shannon Moore          Process if.
# 17      SP0018   Large stock buy oil.     Holly Mitchell   Management artist.
# 20      SP0021          Country real.   Kimberly Bernard  Success investment.
# 23      SP0024             Not start.     Alison Douglas  Trip international.
# 24      SP0025              Consumer.       Patrick Bass               Again.
# ...        ...                    ...                ...                  ...
# 49975  SP49976         Almost action.  Melinda Hernandez               Among.
# 49986  SP49987                Debate.      Gerald Butler          Power like.
# 49989  SP49990        Manage usually.   Christine Campos       Speak mention.
# 49992  SP49993              Sign air.        Ryan Keller                Turn.
# 49995  SP49996    Event push do body.   Shelley Robinson           Wrong cup.
#
# ...

# %%
songs["language"].fillna(130, inplace = True)
songs.head(50)
# Out:
#    song_id                           song_title                  artist  \
# 0   SP0001              Space executive series.            Sydney Clark
# 1   SP0002                 Price last painting.       Connor Peters DDS
# 2   SP0003                               Piece.              Anna Keith
# 3   SP0004                 Power industry your.         Zachary Simpson
# 4   SP0005                  Food animal second.       Christopher Mcgee
# 5   SP0006                    Whatever Mr send.             Nathan King
# 6   SP0007                            Each leg.           Joshua Santos
# 7   SP0008                   Person then enjoy.           Leonard Brown
# 8   SP0009                                Poor.            William Ford
# 9   SP0010                        East husband.           Susan Harrell
# 10  SP0011                Mother building well.           Shannon Moore
# 11  SP0012               Pattern personal tree.             Kenneth Lee
# ...

# %%
songs.loc[5, 'language'] = 'Japanese'
songs.head(8)
# Out:
#   song_id               song_title             artist                album  \
# 0  SP0001  Space executive series.       Sydney Clark                What.
# 1  SP0002     Price last painting.  Connor Peters DDS     Nature politics.
# 2  SP0003                   Piece.         Anna Keith               Visit.
# 3  SP0004     Power industry your.    Zachary Simpson    Behavior evening.
# 4  SP0005      Food animal second.  Christopher Mcgee               Front.
# 5  SP0006        Whatever Mr send.        Nathan King  Various experience.
# 6  SP0007                Each leg.      Joshua Santos           Determine.
# 7  SP0008       Person then enjoy.      Leonard Brown           Sense lot.
#
#         genre release_date  duration  popularity    stream  language  \
# 0  Electronic   1997-11-08     282.0          42  35055874   English
# 1  Electronic   2015-05-10     127.0          50   9249527   English
# 2         Pop   2024-07-08       NaN          10  76669110   English
# ...

# %%
songs.loc[34, 'language'] = 'German'
songs.head(40)
# Out:
#    song_id                           song_title                  artist  \
# 0   SP0001              Space executive series.            Sydney Clark
# 1   SP0002                 Price last painting.       Connor Peters DDS
# 2   SP0003                               Piece.              Anna Keith
# 3   SP0004                 Power industry your.         Zachary Simpson
# 4   SP0005                  Food animal second.       Christopher Mcgee
# 5   SP0006                    Whatever Mr send.             Nathan King
# 6   SP0007                            Each leg.           Joshua Santos
# 7   SP0008                   Person then enjoy.           Leonard Brown
# 8   SP0009                                Poor.            William Ford
# 9   SP0010                        East husband.           Susan Harrell
# 10  SP0011                Mother building well.           Shannon Moore
# 11  SP0012               Pattern personal tree.             Kenneth Lee
# ...
